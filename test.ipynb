# %%
import geopandas as gpd

# %%
gent_cycle_network = gpd.read_file("data\cycle_networks\BE\Arr._Gent-cycle_network.gpkg")
gent_cycle_network.head()
# Out:
#   infra_type  bidirectional   surface smoothness  length_km  scaled_length_km  \
# 0      track           True  concrete        NaN   0.074430          0.074430
# 1       lane           True       NaN        NaN   0.490689          0.490689
# 2       lane          False       NaN        NaN   0.022674          0.011337
# 3       lane          False       NaN        NaN   0.102687          0.051343
# 4       lane          False       NaN        NaN   0.027125          0.013562
#
#                                             geometry
# 0  LINESTRING (3.92203 51.21655, 3.92203 51.21594...
# 1  LINESTRING (3.98555 51.22254, 3.98553 51.22253...
# 2  LINESTRING (3.97902 51.22409, 3.97913 51.22402...
# 3  LINESTRING (3.97804 51.22478, 3.97810 51.22473...
# 4  LINESTRING (3.97777 51.22496, 3.97790 51.22487...

# %%
gent_cycle_network.plot()
# Out:
# <Axes: >

# %%
iww = gpd.read_file("data/TEN-T/iww_GL2017_EU_UK.shp")
railways = gpd.read_file("data/TEN-T/railways_GL2017_EU_UK.shp")
roads = gpd.read_file("data/TEN-T/roads_GL2017_EU_UK.shp")

iww.plot(), railways.plot(), roads.plot()
# Out:
# (<Axes: >, <Axes: >, <Axes: >)

# %%
iww
# Out:
#                   ID COUNTRY_CO MEMBER_STA  \
# 0    151112140257970         DE          1
# 1    151112134652810         DE          1
# 2    150914152853888         BE          1
# 3    150914152040684         BE          1
# 4    150921124543250         NL          1
# ..               ...        ...        ...
# 881  160330150314007         IT          1
# 882  150914145716383         AT          1
# 883  151112133351923         DE          1
# 884  151112133555854         DE          1
# 885  150918141340156         DE          1
#
#                                             DESCRIPTIO CORE_NETWO STAGE_OF_S  \
# 0          Trier (jct. Saar) <--> Koblenz (jct. Mosel)          1  Completed
# 1    Lauenburg (jct. Elbe) <--> Isenbuettel (jct. E...          1  Completed
# 2                         Bocholt <--> Dessel (part 2)          1    Planned
# 3                         Auvelais <--> Namur (part 2)          1  Completed
# ...

# %%
iww_benelux = iww.loc[iww["COUNTRY_CO"].isin(["BE","NL","LUX"])]
railways_benelux = railways.loc[railways["COUNTRY_CO"].isin(["BE","NL","LUX"])]
roads_benelux = roads.loc[roads["COUNTRY_CO"].isin(["BE","NL","LUX"])]

# %%
iww_benelux.plot(), railways_benelux.plot(),roads_benelux.plot()
# Out:
# (<Axes: >, <Axes: >, <Axes: >)

# %%
population_density = gpd.read_file("data\population_density\JRC_GRID_2018\JRC_POPULATION_2018.gpkg")
population_density
# Out:
#                                   GRD_ID CNTR_ID  TOT_P_2018 Country  \
# 0        CRS3035RES1000mN1000000E1966000      ES         103      ES
# 1        CRS3035RES1000mN1000000E1967000      ES           0     NaN
# 2        CRS3035RES1000mN1000000E1979000      ES           0     NaN
# 3        CRS3035RES1000mN1000000E1980000      ES         276      ES
# 4        CRS3035RES1000mN1000000E1981000      ES        1693      ES
# ...                                  ...     ...         ...     ...
# 2416626   CRS3035RES1000mN999000E1979000      ES           0     NaN
# 2416627   CRS3035RES1000mN999000E1980000      ES         256      ES
# 2416628   CRS3035RES1000mN999000E1981000      ES        1543      ES
# 2416629   CRS3035RES1000mN999000E1982000      ES         426      ES
# 2416630   CRS3035RES1000mN999000E1983000      ES          16      ES
#
#                Date                            Method  \
# 0        2018-01-01  Aggregation from fine grid cells
# ...

# %%
population_density_benelux = population_density.loc[population_density["CNTR_ID"].isin(["BE","NL","LUX"])]
population_density_benelux
# Out:
#                                   GRD_ID CNTR_ID  TOT_P_2018 Country  \
# 1217762  CRS3035RES1000mN2945000E3995000      BE         286      BE
# 1218861  CRS3035RES1000mN2946000E3995000      BE          62      BE
# 1218862  CRS3035RES1000mN2946000E3997000      BE           2      BE
# 1219913  CRS3035RES1000mN2947000E3995000      BE         273      BE
# 1219914  CRS3035RES1000mN2947000E3996000      BE         139      BE
# ...                                  ...     ...         ...     ...
# 1725600  CRS3035RES1000mN3381000E4065000      NL          70      NL
# 1725601  CRS3035RES1000mN3381000E4066000      NL         784      NL
# 1725602  CRS3035RES1000mN3381000E4067000      NL          24      NL
# 1725603  CRS3035RES1000mN3381000E4068000      NL          10      NL
# 1726727  CRS3035RES1000mN3382000E4065000      NL          12      NL
#
#                Date                                          Method  \
# 1217762  2018-01-01          Correspondence with snapping 1 km grid
# ...

# %%
population_density_benelux.plot()
# Out:
# <Axes: >

# %%
nuts = gpd.read_file("data/NUTS_regions/NUTS_RG_01M_2021_4326.geojson")
nuts
# Out:
#          id NUTS_ID  LEVL_CODE CNTR_CODE                            NAME_LATN  \
# 0        CZ      CZ          0        CZ                                Česko
# 1        DE      DE          0        DE                          Deutschland
# 2        DK      DK          0        DK                              Danmark
# 3        AL      AL          0        AL                            Shqipëria
# 4        CY      CY          0        CY                               Kýpros
# ...     ...     ...        ...       ...                                  ...
# 2005  UKM73   UKM73          3        UK          East Lothian and Midlothian
# 2006  UKM75   UKM75          3        UK                   Edinburgh, City of
# 2007  UKM76   UKM76          3        UK                              Falkirk
# 2008  UKM78   UKM78          3        UK                         West Lothian
# 2009  UKK24   UKK24          3        UK  Bournemouth, Christchurch and Poole
#
# ...

# %%
nuts_benelux = nuts.loc[nuts["CNTR_CODE"].isin(["BE","NL","LUX"])]
# Out:
# <Axes: >

# %%
nuts_benelux
# Out:
#          id NUTS_ID  LEVL_CODE CNTR_CODE            NAME_LATN  \
# 7        BE      BE          0        BE      Belgique/België
# 34      BE3     BE3          1        BE      Région wallonne
# 35       NL      NL          0        NL            Nederland
# 56      BE2     BE2          1        BE        Vlaams Gewest
# 79      NL4     NL4          1        NL       Zuid-Nederland
# ...     ...     ...        ...       ...                  ...
# 1415  NL225   NL225          3        NL           Achterhoek
# 1416  NL226   NL226          3        NL      Arnhem/Nijmegen
# 1417  NL230   NL230          3        NL            Flevoland
# 1469  NL224   NL224          3        NL  Zuidwest-Gelderland
# 1958  BE329   BE329          3        BE     Arr. La Louvière
#
#                 NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE    FID  \
# 7         Belgique/België         0.0          0           0     BE
# 34        Région wallonne         0.0          0           0    BE3
# ...

# %%
nuts_be = nuts_benelux.loc[nuts_benelux["CNTR_CODE"]=="BE"]
nuts_be
# Out:
#          id NUTS_ID  LEVL_CODE CNTR_CODE  \
# 7        BE      BE          0        BE
# 34      BE3     BE3          1        BE
# 56      BE2     BE2          1        BE
# 110     BE1     BE1          1        BE
# 130    BE34    BE34          2        BE
# 149    BE35    BE35          2        BE
# 157    BE33    BE33          2        BE
# 166    BE24    BE24          2        BE
# 176    BE25    BE25          2        BE
# 190    BE10    BE10          2        BE
# 191    BE21    BE21          2        BE
# 196    BE31    BE31          2        BE
# 198    BE22    BE22          2        BE
# 202    BE23    BE23          2        BE
# 210    BE32    BE32          2        BE
# 400   BE251   BE251          3        BE
# 402   BE335   BE335          3        BE
# 403   BE336   BE336          3        BE
# 440   BE100   BE100          3        BE
# 443   BE334   BE334          3        BE
# 445   BE212   BE212          3        BE
# 446   BE213   BE213          3        BE
# ...

# %%
nuts_gent = nuts_be.loc[nuts_be["NUTS_ID"] == "BE234"]

# %%
nuts_gent.plot(),gent_cycle_network.plot()
# Out:
# (<Axes: >, <Axes: >)
